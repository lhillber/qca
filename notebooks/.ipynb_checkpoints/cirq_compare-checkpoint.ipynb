# %%
from os import path
import numpy as np
import matplotlib.pyplot as plt
from copy import copy
# %matplotlib inline
import pickle

# %%
import sys
sys.path.append("../")  # look one directory up for qca modules, TODO: make a package
from qca import QCA
from measures import fidelity, select_rhojk

# %%
# location of network measure data
der = r"/home/lhillber/documents/research/cellular_automata/qeca/qca/data/circ"
# load .npz files
dat1 = np.load(path.join(der, "exact_clustering_and_disparity.npz"))
dat2 = np.load(path.join(der, "clustering_and_disparity.npz"))

# %%
L = 11
T = 100
rhojs = np.zeros((T, L, 2, 2), dtype=np.complex128)
rhojks = np.zeros((T, L*(L-1)//2, 4, 4), dtype=np.complex128)
jks = [[j,k] for j in range(L) for k in range(j)]
with open(path.join(der,'density_matrices.pickle'), 'rb') as handle:
    data = pickle.load(handle)
    for t in range(T):
        for j in range(L):
            rhojs[t, j, :, :] = data[f"t{t}_r0_q{j}"]
        for i, (j, k) in enumerate(jks):
            rhojks[t,i,:,:] = data[f"t{t}_r0_q{k}_qq{j}"]
            c += 1

# %%
import measures as ms

# %%
# unpack data: 1 = exact, 2 = quantum overlap tomography (QOT)
C1 = dat1["arr_1"]
Y1 = dat1["arr_2"]
C2 = dat2["arr_1"]
Y2 = dat2["arr_2"]
# Absolute difference
Cdiff = np.abs(C2-C1)
Ydiff = np.abs(Y2-Y1)

# %%
fig, axs = plt.subplots(2, 2, sharex="col")
axs[0,0].plot(C1, label="exact")
axs[0,0].plot(C2, label="QOT")
axs[0,0].set_ylabel(r"Clustering")

axs[1,0].plot(Cdiff, c="k")
axs[1,0].set_yscale("log")
axs[1,0].set_ylabel("Clustering difference")
axs[1,0].set_xlabel(r"Time")

axs[0,1].plot(Y1, label="exact")
axs[0,1].plot(Y2, label="QOT")
axs[0,1].legend(loc="upper right")
axs[0,1].set_ylabel("Disparity")

axs[1,1].plot(Ydiff, c="k")
axs[1,1].set_yscale("log")
axs[1,1].set_ylabel("Disparity difference")
axs[1,1].set_xlabel(r"Time, $t$")

plt.tight_layout()
plt.savefig("circ_network_measure_accuracy.pdf")

# %%
F = np.array([[fidelity(rj, sj) for rj, sj in zip(Q1.rhoj[t], rhojs[t])] for t in range(T)])
F2 = np.array([[fidelity(rj, sj) for rj, sj in zip(Q1.rhojk[t], rhojks[t])] for t in range(T)])

# %%
plt.plot(np.mean(F, axis=1))
plt.plot(np.mean(F2, axis=1))

# %%
rhojks[1,4]
# Out:
# array([[ 7.78e-01+0.j    ,  2.48e-01+0.013j , -7.50e-03+0.0105j,
#         -5.50e-03-0.0165j],
#        [ 2.48e-01-0.013j ,  2.22e-01+0.j    ,  5.00e-04+0.0105j,
#          1.15e-02+0.0035j],
#        [-7.50e-03-0.0105j,  5.00e-04-0.0105j,  0.00e+00+0.j    ,
#          7.00e-03-0.011j ],
#        [-5.50e-03+0.0165j,  1.15e-02-0.0035j,  7.00e-03+0.011j ,
#          0.00e+00+0.j    ]])

# %%
Q1.rhojk[1,4]
# Out:
# array([[0.75+0.j, 0.  +0.j, 0.25+0.j, 0.  +0.j],
#        [0.  +0.j, 0.  +0.j, 0.  +0.j, 0.  +0.j],
#        [0.25+0.j, 0.  +0.j, 0.25+0.j, 0.  +0.j],
#        [0.  +0.j, 0.  +0.j, 0.  +0.j, 0.  +0.j]])

# %%
p1 = dict(
              L=11,
              T=200.0,
              dt=1.0,
              R=6,
              r=1,
              V="H",
              BC="1-00",
              IC="c1_f0",
              E=0.0,
              N=1,
              totalistic=False,
              hamiltonian=False,
              trotter=True,
              symmetric=False)
p2 = copy(p1)
p2.update({"N":200, "E":0.0068})

Q1 = QCA(p1, der=r"/home/lhillber/documents/research/cellular_automata/qeca/qca/data/")
Q2 = QCA(p2, der=r"/home/lhillber/documents/research/cellular_automata/qeca/qca/data/")

F = np.array([[fidelity(rj, sj) for rj, sj in zip(Q1.rhoj[t], Q2.rhoj[t])] for t in Q1.ts.astype(int)])
F2 = np.array([[fidelity(rj, sj) for rj, sj in zip(Q1.rhojk[t], Q2.rhojk[t])] for t in Q1.ts.astype(int)])

C1 = Q1.C(2)
C2 = Q2.C(2)

Y1 = Q1.Y(2)
Y2 = Q2.Y(2)


#Q1.close()
#Q2.close()

# %%
plt.imshow(F[:100], origin="lower")

# %%
plt.plot(np.mean(F, axis=1))
plt.plot(np.mean(F2, axis=1))

# %%
plt.plot((C1-C2))
plt.plot((Y2-Y1))
